# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config import *
import os
import tensorflow as tf; print('tensorflow', tf.__version__)
import keras; print('keras', keras.__version__)
# Out:
# tensorflow 1.14.0
# keras 2.2.4
# Using TensorFlow backend.

# %%
# from preprocess import Preprocess

# %%
# pre = Preprocess()
# pre.handle()

# %%
# set gpu visible environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config = tf.ConfigProto()

# gpu allow_growth
config.gpu_options.allow_growth = True
keras.backend.set_session(tf.Session(config=config))

# %% [markdown]
# ## Lung Segmentation, Focus 1,5

# %%
from train_segmentation import seg_train

# %%
seg_train("lung",0.00003,'./output/training_logs/seg-run-lung-11-7/lung_checkpoint-01-0.6145.hdf5')#,'./weight/lung_seg_jijie_0.49.hdf5'
# Out:
# start seg_train
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 64, 64, 64, 1 0
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 64, 64, 64, 3 896         input_2[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 64, 64, 64, 3 27680       conv3d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_5 (MaxPooling3D)  (None, 32, 32, 32, 3 0           conv3d_21[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 32, 32, 32, 6 55360       max_pooling3d_5[0][0]
# ...

# %% [markdown]
# ## Lung Classfication, Focus 1,5

# %%
from train_classification import classify_train

# %%
classify_train("lung",0.000001,'./weight/lung_class_0.86.hdf5')
# Out:
# start classify_train
# base
# (?, 32, 32, 32, 16)
# resnet block, shrinkage:True
# (?, 32, 32, 32, 16)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:False
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:False
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:False
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:True
# (?, 16, 16, 16, 32)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:False
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:False
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:False
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:True
# (?, 8, 8, 8, 64)
# (?, 4, 4, 4, 128)
# (?, 4, 4, 4, 128)
# resnet block, shrinkage:False
# (?, 4, 4, 4, 128)
# (?, 4, 4, 4, 128)
# (?, 4, 4, 4, 128)
# ...

# %% [markdown]
# ## Mediastinal Segmentation, Focus 31,32

# %%
from train_segmentation import seg_train
seg_train("mediastinal",0.0001,'./weight/mediastinal_seg_0.5930.hdf5')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0729 10:37:48.808132 140092017075968 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0729 10:37:48.809501 140092017075968 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0729 10:37:48.813481 140092017075968 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %% [markdown]
# ## Mediastinal Classfication, Focus 31,32

# %%
from train_classification import classify_train

# %%
classify_train("mediastinal",TRAIN_CLASSIFY_LEARNING_RATE)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 15:28:31.550000 140580751664896 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0726 15:28:31.551268 140580751664896 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0726 15:28:31.564046 140580751664896 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...
