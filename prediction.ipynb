# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config import *
import os
import tensorflow as tf; print('tensorflow', tf.__version__)
import keras; print('keras', keras.__version__)
# Out:
# tensorflow 1.14.0
# keras 2.2.4
# Using TensorFlow backend.

# %%
#set gpu visible environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config = tf.ConfigProto()

# gpu allow_growth
config.gpu_options.allow_growth = True
keras.backend.set_session(tf.Session(config=config))

# %%
from predict import predict_test

# %%
predict_test('lung','test','./weight/lung_seg_jijie_0.49.hdf5','./weight/lung_class_0.86.hdf5',0.8,[50,50])# './weight/lung_seg_0.6646.hdf5'

# %%
predict_test('lung','test','./weight/lung_seg_suotiao_0.61.hdf5','./weight/lung_class_0.86.hdf5',0.8,[50,50])# './weight/lung_seg_0.6646.hdf5'

# %%
#Genearte mediastinal from 50,50 to shap-50,shape-50
predict_test('mediastinal','test','./output/training_logs/seg-run-mediastinal-10-38/mediastinal_checkpoint-02-0.5249.hdf5','./weight/mediastinal_class_0.95.hdf5',0.8,[50,50])
# Out:
# base
# (?, 32, 32, 32, 16)
# resnet block, shrinkage:True
# (?, 32, 32, 32, 16)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:False
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:False
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:False
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# (?, 16, 16, 16, 32)
# resnet block, shrinkage:True
# (?, 16, 16, 16, 32)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:False
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:False
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:False
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# (?, 8, 8, 8, 64)
# resnet block, shrinkage:True
# (?, 8, 8, 8, 64)
# (?, 4, 4, 4, 128)
# (?, 4, 4, 4, 128)
# resnet block, shrinkage:False
# (?, 4, 4, 4, 128)
# (?, 4, 4, 4, 128)
# (?, 4, 4, 4, 128)
# resnet block, shrinkage:False
# ...
